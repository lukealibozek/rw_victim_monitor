# %% [markdown]
# # Setup
# ---

# %%
pip install python-whois
# Out:
# Collecting python-whois
#   Downloading python-whois-0.8.0.tar.gz (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /Users/lucasalibozek/opt/anaconda3/envs/cti/lib/python3.9/site-packages (from python-whois) (0.18.3)
# Building wheels for collected packages: python-whois
#   Building wheel for python-whois (setup.py) ... done
#   Created wheel for python-whois: filename=python_whois-0.8.0-py3-none-any.whl size=103247 sha256=88d795adb088d203c9b0f9b15994f559d706f366b7dac29fc9b2c0cf32b071a4
#   Stored in directory: /Users/lucasalibozek/Library/Caches/pip/wheels/ae/82/fc/e18098cced79fecb8ce92b4ba150993a3c07d404eae54a12f7
# Successfully built python-whois
# Installing collected packages: python-whois
# Successfully installed python-whois-0.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from lxml import etree
import re

url = "https://www.inoreader.com/stream/user/1004920918/tag/Py%3A%20Ransomware%20monitor"

# fetch the RSS feed
response = requests.get(url)
# print(response)

# parse the XML using lxml
root = etree.fromstring(response.content)

# define the namespace mapping
ns = {"rss": "http://purl.org/rss/1.0/"}

# loop through all the <item> elements and extract the victim name and ransomware name
for item in root.xpath("//item", namespaces=ns):
    link = item.xpath("./link/text()", namespaces=ns)[0]
    title = item.xpath("./title/text()", namespaces=ns)[0]
    actor = re.search(r'Actor\s*:\s*(\w+)', title).group(1)
    print("Actor:", actor)
    # Extracting the victim
    victim = re.search(r'Victim\s*:\s*(\w+)', title)
    print("Victim:", victim)
    # Extracting the date
    date = re.search(r'Date\s*:\s*(\d{4}-\d{2}-\d{2})', title).group(1)
    print("Date:", date)
# Out:
# Actor: medusa
# Victim: <re.Match object; span=(18, 35), match='Victim : Arandell'>
# Date: 2023-04-02
# Actor: BlackCat
# Victim: <re.Match object; span=(28, 45), match='Victim : TRUSSWAY'>
# Date: 2023-04-01
# Actor: royal
# Victim: <re.Match object; span=(17, 33), match='Victim : Vending'>
# Date: 2023-04-01
# Actor: royal
# Victim: <re.Match object; span=(17, 33), match='Victim : Benning'>
# Date: 2023-04-01
# Actor: LockBit
# Victim: <re.Match object; span=(19, 33), match='Victim : https'>
# Date: 2023-04-01
# Actor: LockBit
# Victim: <re.Match object; span=(19, 33), match='Victim : https'>
# Date: 2023-03-31
# Actor: karakurt
# Victim: <re.Match object; span=(20, 42), match='Victim : OptionMetrics'>
# Date: 2023-03-31
# Actor: LockBit
# Victim: <re.Match object; span=(19, 33), match='Victim : https'>
# Date: 2023-03-31
# Actor: royal
# Victim: <re.Match object; span=(17, 31), match='Victim : https'>
# Date: 2023-03-31
# Actor: royal
# Victim: <re.Match object; span=(17, 35), match='Victim : Armstrong'>
# Date: 2023-03-31
# Actor: Vice
# Victim: <re.Match object; span=(23, 37), match='Victim : Lewis'>
# Date: 2023-03-31
# Actor: Vice
# Victim: <re.Match object; span=(24, 38), match='Victim : Lewis'>
# Date: 2023-03-31
# Actor: LockBit
# Victim: <re.Match object; span=(19, 33), match='Victim : https'>
# Date: 2023-03-31
# Actor: STORMOUS
# Victim: <re.Match object; span=(20, 34), match='Victim : MELCO'>
# Date: 2023-03-30
# Actor: STORMOUS
# Victim: <re.Match object; span=(20, 35), match='Victim : ieseco'>
# Date: 2023-03-30
# Actor: STORMOUS
# Victim: <re.Match object; span=(20, 43), match='Victim : matrixtelecoms'>
# Date: 2023-03-30
# Actor: STORMOUS
# Victim: <re.Match object; span=(20, 34), match='Victim : https'>
# Date: 2023-03-30
# Actor: CLOP
# Victim: <re.Match object; span=(22, 36), match='Victim : https'>
# Date: 2023-03-30
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 21
#      19 link = item.xpath("./link/text()", namespaces=ns)[0]
#      20 title = item.xpath("./title/text()", namespaces=ns)[0]
# ---> 21 actor = re.search(r'Actor\s*:\s*(\w+)', title).group(1)
#      22 print("Actor:", actor)
#      23 # Extracting the victim
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import whois

# Make a GET request to the website
url = "https://www.redpacketsecurity.com/category/ransomware/"
response = requests.get(url)

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Find all the blog post titles and print them
blog_entries = soup.find_all("article", class_="small")
for entry in blog_entries:
    title = entry.find("h4", class_="entry-title")
    victim = title.text.split("Ransomware Victim: ")[1].split()
    victim = ' '.join(victim)
    ransomware = title.text.split("Ransomware Victim: ")[0].split()
    ransomware = ' '.join(ransomware)
    link = title.a["href"]
    date = entry.find("span", class_="mg-blog-date")
    date = pd.to_datetime(date.a.text).strftime('%Y-%m-%d')
    print(f"{date} {ransomware} - {victim} ({link})")
# Out:
# module 'whois' has no attribute 'whois'
# google.com
# module 'whois' has no attribute 'whois'
# 2023-04-03 LockBit 3.0 - revvaviation.com (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-revvaviation-com/)
# module 'whois' has no attribute 'whois'
# 2023-04-03 LockBit 3.0 - gdz.com (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-gdz-com/)
# module 'whois' has no attribute 'whois'
# 2023-04-03 RansomHouse - Aero Engine Solution INC (https://www.redpacketsecurity.com/ransomhouse-ransomware-victim-aero-engine-solution-inc/)
# module 'whois' has no attribute 'whois'
# 2023-04-03 Cl0p - LASOTEL.FR (https://www.redpacketsecurity.com/cl0p-ransomware-victim-lasotel-fr/)
# module 'whois' has no attribute 'whois'
# 2023-04-02 LockBit 3.0 - p-and-r.com (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-p-and-r-com/)
# module 'whois' has no attribute 'whois'
# 2023-04-01 LockBit 3.0 - semsinc.net (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-semsinc-net/)
# module 'whois' has no attribute 'whois'
# 2023-04-01 LockBit 3.0 - etkinllc.com (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-etkinllc-com/)
# module 'whois' has no attribute 'whois'
# 2023-04-01 LockBit 3.0 - ativy.com (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-ativy-com/)
# module 'whois' has no attribute 'whois'
# 2023-04-01 Karakurt - OptionMetrics (https://www.redpacketsecurity.com/karakurt-ransomware-victim-optionmetrics/)
# module 'whois' has no attribute 'whois'
# 2023-03-31 LockBit 3.0 - okcu.edu (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-okcu-edu/)
# module 'whois' has no attribute 'whois'
# 2023-03-31 LockBit 3.0 - theus-industries.fr (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-theus-industries-fr/)
# module 'whois' has no attribute 'whois'
# 2023-03-31 LockBit 3.0 - hacla.org part 2 (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-hacla-org-part/)
# module 'whois' has no attribute 'whois'
# 2023-03-31 LockBit 3.0 - statravel.de (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-statravel-de/)
# module 'whois' has no attribute 'whois'
# 2023-03-31 LockBit 3.0 - groupe-seche.com (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-groupe-seche-com/)
# module 'whois' has no attribute 'whois'
# 2023-03-31 Vice Society - Lewis & Clark College (https://www.redpacketsecurity.com/vice-ransomware-victim-lewis-amp-clark-college/)
# module 'whois' has no attribute 'whois'
# 2023-03-31 Cl0p - MULTIPLAN.COM (https://www.redpacketsecurity.com/cl0p-ransomware-victim-multiplan-com/)
# module 'whois' has no attribute 'whois'
# 2023-03-30 LockBit 3.0 - tharworx.com (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-tharworx-com/)
# module 'whois' has no attribute 'whois'
# 2023-03-30 LockBit 3.0 - overseas-ast.com (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-overseas-ast-com/)
# module 'whois' has no attribute 'whois'
# 2023-03-30 LockBit 3.0 - hammondlumber.com (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-hammondlumber-com/)
# module 'whois' has no attribute 'whois'
# 2023-03-30 RansomHouse - Hospital Clinic de Barcelona (https://www.redpacketsecurity.com/ransomhouse-ransomware-victim-hospital-clinic-de-barcelona/)
# module 'whois' has no attribute 'whois'
# 2023-03-30 Karakurt - FINANCE INSTITUTION AUCTION (https://www.redpacketsecurity.com/karakurt-ransomware-victim-finance-institution-auction/)
# module 'whois' has no attribute 'whois'
# 2023-03-29 LockBit 3.0 - nts.go.kr (https://www.redpacketsecurity.com/lockbit-3-0-ransomware-victim-nts-go-kr/)
# module 'whois' has no attribute 'whois'
# 2023-03-29 Karakurt - MICROFINANCE INSTITUTION (https://www.redpacketsecurity.com/karakurt-ransomware-victim-microfinance-institution/)
# module 'whois' has no attribute 'whois'
# 2023-03-29 RansomHouse - AV Industries (https://www.redpacketsecurity.com/ransomhouse-ransomware-victim-av-industries/)

# %%
pip install --upgrade python-whois
# Out:
# Requirement already satisfied: python-whois in /Users/lucasalibozek/opt/anaconda3/envs/cti/lib/python3.9/site-packages (0.8.0)
# Requirement already satisfied: future in /Users/lucasalibozek/opt/anaconda3/envs/cti/lib/python3.9/site-packages (from python-whois) (0.18.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import whois

def get_company_name(domain):
    try:
        w = whois.whois(domain)
        return w.text
    except Exception as e:
        print(e)
        return "ummm"

# Example usage
domain = 'wwe.com'
company_name = get_company_name(domain)
print(company_name)
# Out:
#    Domain Name: WWE.COM
#    Registry Domain ID: 584553_DOMAIN_COM-VRSN
#    Registrar WHOIS Server: whois.markmonitor.com
#    Registrar URL: http://www.markmonitor.com
#    Updated Date: 2022-04-27T09:14:38Z
#    Creation Date: 1995-05-30T04:00:00Z
#    Registry Expiry Date: 2024-05-29T04:00:00Z
#    Registrar: MarkMonitor Inc.
#    Registrar IANA ID: 292
#    Registrar Abuse Contact Email: abusecomplaints@markmonitor.com
#    Registrar Abuse Contact Phone: +1.2086851750
#    Domain Status: clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited
#    Domain Status: clientTransferProhibited https://icann.org/epp#clientTransferProhibited
#    Domain Status: clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited
#    Domain Status: serverDeleteProhibited https://icann.org/epp#serverDeleteProhibited
#    Domain Status: serverTransferProhibited https://icann.org/epp#serverTransferProhibited
#    Domain Status: serverUpdateProhibited https://icann.org/epp#serverUpdateProhibited
#    Name Server: NS1.WWE.COM
#    Name Server: NS2.WWE.COM
#    Name Server: NS3.WWE.COM
#    Name Server: NS5.DNSMADEEASY.COM
#    Name Server: NS6.DNSMADEEASY.COM
#    Name Server: NS7.DNSMADEEASY.COM
#    DNSSEC: unsigned
#    URL of the ICANN Whois Inaccuracy Complaint Form: https://www.icann.org/wicf/
# >>> Last update of whois database: 2023-04-03T21:01:32Z <<<
#
# For more information on Whois status codes, please visit https://icann.org/epp
#
# NOTICE: The expiration date displayed in this record is the date the
# registrar's sponsorship of the domain name registration in the registry is
# currently set to expire. This date does not necessarily reflect the expiration
# date of the domain name registrant's agreement with the sponsoring
# registrar.  Users may consult the sponsoring registrar's Whois database to
# view the registrar's reported date of expiration for this registration.
#
# TERMS OF USE: You are not authorized to access or query our Whois
# database through the use of electronic processes that are high-volume and
# automated except as reasonably necessary to register domain names or
# modify existing registrations; the Data in VeriSign Global Registry
# Services' ("VeriSign") Whois database is provided by VeriSign for
# information purposes only, and to assist persons in obtaining information
# about or related to a domain name registration record. VeriSign does not
# guarantee its accuracy. By submitting a Whois query, you agree to abide
# by the following terms of use: You agree that you may use this Data only
# for lawful purposes and that under no circumstances will you use this Data
# to: (1) allow, enable, or otherwise support the transmission of mass
# unsolicited, commercial advertising or solicitations via e-mail, telephone,
# or facsimile; or (2) enable high volume, automated, electronic processes
# that apply to VeriSign (or its computer systems). The compilation,
# repackaging, dissemination or other use of this Data is expressly
# prohibited without the prior written consent of VeriSign. You agree not to
# use electronic processes that are automated and high-volume to access or
# query the Whois database except as reasonably necessary to register
# domain names or modify existing registrations. VeriSign reserves the right
# to restrict your access to the Whois database in its sole discretion to ensure
# operational stability.  VeriSign may restrict or terminate your access to the
# Whois database for failure to abide by these terms of use. VeriSign
# reserves the right to modify these terms at any time.
#
# The Registry database contains ONLY .COM, .NET, .EDU domains and
# Registrars.
# Domain Name: wwe.com
# Registry Domain ID: 584553_DOMAIN_COM-VRSN
# Registrar WHOIS Server: whois.markmonitor.com
# Registrar URL: http://www.markmonitor.com
# Updated Date: 2022-04-27T09:14:38+0000
# Creation Date: 1995-05-30T07:00:00+0000
# Registrar Registration Expiration Date: 2024-05-29T00:00:00+0000
# Registrar: MarkMonitor, Inc.
# Registrar IANA ID: 292
# Registrar Abuse Contact Email: abusecomplaints@markmonitor.com
# Registrar Abuse Contact Phone: +1.2086851750
# Domain Status: clientUpdateProhibited (https://www.icann.org/epp#clientUpdateProhibited)
# Domain Status: clientTransferProhibited (https://www.icann.org/epp#clientTransferProhibited)
# Domain Status: clientDeleteProhibited (https://www.icann.org/epp#clientDeleteProhibited)
# Domain Status: serverUpdateProhibited (https://www.icann.org/epp#serverUpdateProhibited)
# Domain Status: serverTransferProhibited (https://www.icann.org/epp#serverTransferProhibited)
# Domain Status: serverDeleteProhibited (https://www.icann.org/epp#serverDeleteProhibited)
# Registrant Organization: World Wrestling Entertainment, Inc.
# Registrant State/Province: CT
# Registrant Country: US
# Registrant Email: Select Request Email Form at https://domains.markmonitor.com/whois/wwe.com
# Admin Organization: World Wrestling Entertainment, Inc.
# Admin State/Province: CT
# Admin Country: US
# Admin Email: Select Request Email Form at https://domains.markmonitor.com/whois/wwe.com
# Tech Organization: World Wrestling Entertainment, Inc.
# Tech State/Province: CT
# Tech Country: US
# Tech Email: Select Request Email Form at https://domains.markmonitor.com/whois/wwe.com
# Name Server: ns3.wwe.com
# Name Server: ns1.wwe.com
# Name Server: ns7.dnsmadeeasy.com
# Name Server: ns6.dnsmadeeasy.com
# Name Server: ns2.wwe.com
# Name Server: ns5.dnsmadeeasy.com
# DNSSEC: unsigned
# URL of the ICANN WHOIS Data Problem Reporting System: http://wdprs.internic.net/
# >>> Last update of WHOIS database: 2023-04-03T21:00:49+0000 <<<
#
# For more information on WHOIS status codes, please visit:
#   https://www.icann.org/resources/pages/epp-status-codes
#
# If you wish to contact this domain’s Registrant, Administrative, or Technical
# contact, and such email address is not visible above, you may do so via our web
# form, pursuant to ICANN’s Temporary Specification. To verify that you are not a
# robot, please enter your email address to receive a link to a page that
# facilitates email communication with the relevant contact(s).
#
# Web-based WHOIS:
#   https://domains.markmonitor.com/whois
#
# If you have a legitimate interest in viewing the non-public WHOIS details, send
# your request and the reasons for your request to whoisrequest@markmonitor.com
# and specify the domain name in the subject line. We will review that request and
# may ask for supporting documentation and explanation.
#
# The data in MarkMonitor’s WHOIS database is provided for information purposes,
# and to assist persons in obtaining information about or related to a domain
# name’s registration record. While MarkMonitor believes the data to be accurate,
# the data is provided "as is" with no guarantee or warranties regarding its
# accuracy.
#
# By submitting a WHOIS query, you agree that you will use this data only for
# lawful purposes and that, under no circumstances will you use this data to:
#   (1) allow, enable, or otherwise support the transmission by email, telephone,
# or facsimile of mass, unsolicited, commercial advertising, or spam; or
#   (2) enable high volume, automated, or electronic processes that send queries,
# data, or email to MarkMonitor (or its systems) or the domain name contacts (or
# its systems).
#
# MarkMonitor reserves the right to modify these terms at any time.
#
# By submitting this query, you agree to abide by this policy.
#
# MarkMonitor Domain Management(TM)
# Protecting companies and consumers in a digital world.
#
# Visit MarkMonitor at https://www.markmonitor.com
# Contact us at +1.8007459229
# In Europe, at +44.02032062220
# --

# %% [markdown]
# #### Set URL Variables

# %%
rss_url = "https://www.inoreader.com/stream/user/1004920918/tag/Py%3A%20Ransomware%20monitor"

# %% [markdown]
# # Import CSV Database
# ---

# %%
# df_csv = pd.read_csv('cve_db.csv')
# df_csv.dtypes

# %% [markdown]
# # Pull RSS Feed
# ---

# %%
# Download the RSS feed
response = requests.get(rss_url)

# Parse the XML feed using lxml
root = etree.fromstring(response.content)

# define the namespace used in the RSS feed
ns = {'rss': 'http://www.w3.org/2005/Atom'}

# Get the list of items in the feed
items = root.xpath("//item")

# %%
from lxml import etree

# parse the RSS feed
# rss = etree.parse('rss_feed.xml')

# iterate over the items in the feed
for item in items:
    # extract the victim name
    victim_name = title = item.xpath("title")[0].text.replace('\n',' ')
    
    # # extract the ransomware name
    # ransomware_name = item.xpath('.//rss:div/text()', namespaces=ns)[0]
    
    # # extract the source URL
    # source_url = item.xpath('.//rss:link/text()', namespaces=ns)[0]
    
    # # extract the source title
    # source_title = item.xpath('.//rss:title/text()', namespaces=ns)[0]
    
    # print the extracted information
    print(f"Victim name: {victim_name}")
    # print(f"Ransomware name: {ransomware_name}")
    # print(f"Source URL: {source_url}")
    # print(f"Source title: {source_title}\n")
# Out:
# Victim name: LockBit 3.0 Ransomware Victim: revvaviation[.]com
# Victim name: LockBit 3.0 Ransomware Victim: gdz[.]com
# Victim name: RansomHouse Ransomware Victim: Aero Engine Solution INC
# Victim name: Cl0p Ransomware Victim: LASOTEL[.]FR
# Victim name: Actor : medusa    Victim : Arandell Corp    Date : 2023-04-02 08:34 UTC +3       According to the #DarkWeb #Ransomware activity by the ThreatMon Threat Intelligence Team, the “#medusa” Ransomware group has added Arandell Corp to its victims.
# Victim name: LockBit 3.0 Ransomware Victim: p-and-r[.]com
# Victim name: LockBit 3.0 Ransomware Victim: etkinllc[.]com
# Victim name: LockBit 3.0 Ransomware Victim: ativy[.]com
# Victim name: LockBit 3.0 Ransomware Victim: semsinc[.]net
# Victim name: Actor : BlackCat (ALPHV)    Victim : TRUSSWAY    Date : 2023-04-01 13:19 UTC +3       According to the #DarkWeb #Ransomware activity by the ThreatMon Threat Intelligence Team, the “#BlackCat(ALPHV)” Ransomware group has added TRUSSWAY to its victims.
# Victim name: Actor : royal    Victim : Vending Group    Date : 2023-04-01 09:18 UTC +3       According to the #DarkWeb #Ransomware activity by the ThreatMon Threat Intelligence Team, the “#royal” Ransomware group has added Vending Group to its victims.
# Victim name: Actor : royal    Victim : Benning Construction    Date : 2023-04-01 09:18 UTC +3       According to the #DarkWeb #Ransomware activity by the ThreatMon Threat Intelligence Team, the “#royal” Ransomware group has added Benning Construction to its victims.
# Victim name: Karakurt Ransomware Victim: OptionMetrics
# Victim name: Actor : LockBit    Victim : https://t.co/7HR0er2fkU    Date : 2023-04-01 03:18 UTC +3       According to the #DarkWeb #Ransomware activity by the ThreatMon Threat Intelligence Team, the “#LockBit” Ransomware group has added https://t.co/7HR0er2fkU to its victims.
# Victim name: Actor : LockBit    Victim : https://t.co/HGxHi5u9FH    Date : 2023-03-31 19:20 UTC +3       According to the #DarkWeb #Ransomware activity by the ThreatMon Threat Intelligence Team, the “#LockBit” Ransomware group has added https://t.co/HGxHi5u9FH to its victims.
# Victim name: Leaked Reality – 114,907 breached accounts
# Victim name: Sundry Files – 274,461 breached accounts
# Victim name: Actor : karakurt    Victim : OptionMetrics    Date : 2023-03-31 17:18 UTC +3       According to the #DarkWeb #Ransomware activity by the ThreatMon Threat Intelligence Team, the “#karakurt” Ransomware group has added OptionMetrics to its victims.
# Victim name: Actor : LockBit    Victim : https://t.co/h6k2uNyCgY    Date : 2023-03-31 12:35 UTC +3       According to the #DarkWeb #Ransomware activity by the ThreatMon Threat Intelligence Team, the “#LockBit” Ransomware group has added https://t.co/h6k2uNyCgY to its victims.
# Victim name: Actor : royal    Victim : https://t.co/5fm4wC93kK    Date : 2023-03-31 12:35 UTC +3       According to the #DarkWeb #Ransomware activity by the ThreatMon Threat Intelligence Team, the “#royal” Ransomware group has added https://t.co/5fm4wC93kK to its victims.

# %%
# # Define an empty list to store the CVE data
# cve_data = []
# # Set to track unique CVEs
# unique_cve = set()
# Set current time variable
current_time = datetime.today().strftime('%Y-%m-%d')

# Iterate over the items and extract the CVE data
for item in items:
    title = item.xpath("title")[0].text.replace('\n',' ')
    title = title.replace('\t',' ')
    title = title.replace('  ',' ')
    link = item.xpath("link")[0].text
    description = item.xpath("description")[0].text
    pub_date = item.xpath("pubDate")[0].text
    pub_date = pd.to_datetime(pub_date[5:])

    # Extract the CVE identifiers from the description
    cves = re.findall(r'(CVE-\d{4}-\d{4,7})', description)

    # Append the CVE data to the list
    for cve in cves:
        cve_data.append({"cve_ID": cve,
        "tweet_content": title, 
        "tweet_url": link, 
        "date_scraped": current_time, 
        "date_published": pd.to_datetime(pub_date).strftime('%Y-%m-%d'),
        "report_key": cve+link
        })
        unique_cve.update(cves)

# Create a DataFrame from the CVE data
df_cve_main = pd.DataFrame(cve_data)
df_cve_main.head()
# Out:
#            cve_ID                                      tweet_content  \
# 0  CVE-2023-23752  Joomla Web Service Endpoint Access (CVE-2023-2...
# 1   CVE-2020-2551  hktalent/CVE-2020-2551: how detect CVE-2020-25...
# 2   CVE-2020-2551  hktalent/CVE-2020-2551: how detect CVE-2020-25...
# 3  CVE-2020-24550  CVE-2020-24550 poc    https://t.co/7alcxZ3to0 ...
# 4  CVE-2022-44268  The Bug Bounty Hunter:  A PoC for the CVE-2022...
#
#                                            tweet_url date_scraped  \
# 0  https://twitter.com/akaclandestine/status/1642...   2023-04-03
# 1  https://twitter.com/Paula_Piccard/status/16424...   2023-04-03
# 2  https://twitter.com/Paula_Piccard/status/16424...   2023-04-03
# 3  https://twitter.com/karthithehacker/status/164...   2023-04-03
# 4  https://twitter.com/bugbounty0/status/16423431...   2023-04-03
#
#   date_published                                         report_key
# 0     2023-04-02  CVE-2023-23752https://twitter.com/akaclandesti...
# 1     2023-04-02  CVE-2020-2551https://twitter.com/Paula_Piccard...
# 2     2023-04-02  CVE-2020-2551https://twitter.com/Paula_Piccard...
# 3     2023-04-02  CVE-2020-24550https://twitter.com/karthithehac...
# 4     2023-04-02  CVE-2022-44268https://twitter.com/bugbounty0/s...

# %% [markdown]
# ### Update Older Entries

# %%
# # Locate all older entries that are not in KEV
df_missing_nvd = df_csv.loc[(df_csv['kev_present'] == False)] #CHECK - ensure same as what is being input for missing fields
# # Combine missing entries with CVE list
df_cve_main = pd.concat([df_missing_nvd,df_cve_main],ignore_index=True)
# # Remove duplicates
df_cve_main.drop_duplicates('report_key', inplace = True)

# Length before concat
before = len(unique_cve)
# COMMENT OUT TO PREVENT UPDATE OF OLDER ENTRIES
unique_cve.update(df_cve_main['cve_ID'])
# Length after concat
after = len(unique_cve)
# Print stats
print(f'Before: {before}, After: {after}')
# print(df_cve_main)
# Out:
# Before: 21, After: 31

# %%
nvd_table = []
default_zero = pd.to_datetime('1900-01-01').strftime('%Y-%m-%d')
current_time = pd.Timestamp.now()

for x in unique_cve:
    nvd_response = requests.get(f'{NVD_BASE_URL}{x}')
    json_data = nvd_response.json()
    
    try:
        nvd_description = json_data['vulnerabilities'][0]['cve']['descriptions'][0]['value']
        nvd_present = True
    except:
        nvd_description = 'no data'
        nvd_present = False
    try:
        cve_dict = json_data['vulnerabilities'][0]['cve']
    except:
        cve_dict = {}

    nvd_published = cve_dict.get('published',default_zero)
    nvd_lastModified = cve_dict.get('lastModified',default_zero)
    nvd_vulnStatus = cve_dict.get('vulnStatus','*no data*')
    nvd_cisaExploitAdd = cve_dict.get('cisaExploitAdd',default_zero)
    nvd_cisaVulnerabilityName = cve_dict.get('cisaVulnerabilityName','*no data*')
    bulk_references = cve_dict.get('references','*no data*')
    nvd_references = []
    if bulk_references == '*no data*':
        next
    else:
        for i in bulk_references:
            nvd_references.append(i['url'])
    try:
        cvss_data_dict = json_data['vulnerabilities'][0]['cve']['metrics']['cvssMetricV31'][0]['cvssData']
    except:
        cvss_data_dict = {}

    nvd_attackVector = cvss_data_dict.get('attackVector','*no data*')
    nvd_attackComplexity = cvss_data_dict.get('attackComplexity','*no data*')
    nvd_privilegesRequired = cvss_data_dict.get('privilegesRequired','*no data*')
    nvd_userInteraction = cvss_data_dict.get('userInteraction','no data')
    nvd_baseScore = cvss_data_dict.get('baseScore','*no data*')
    nvd_baseSeverity = cvss_data_dict.get('baseSeverity','*no data*')

    try:
        nvd_exploitabilityScore = json_data['vulnerabilities'][0]['cve']['metrics']['cvssMetricV31'][0]['exploitabilityScore']
    except:
        nvd_exploitabilityScore = '*no data*'
    try:
        nvd_impactScore = json_data['vulnerabilities'][0]['cve']['metrics']['cvssMetricV31'][0]['impactScore']
    except:
        nvd_impactScore = ''

    if nvd_cisaExploitAdd == default_zero:
        kev_present = False
        kev_dateDelta = 0
        kev_category = "1. Not in KEV"
    else:
        kev_present = True
        kev_dateDelta = pd.to_datetime(current_time) - pd.to_datetime(nvd_cisaExploitAdd)
        kev_dateDelta = kev_dateDelta.days
        if kev_dateDelta > 30:
            kev_category = "3. KEV, Old (>30)"
        else:
            kev_category = "2. KEV, New (0-30)" 

    print(f'{x}\nBase Score: {nvd_baseScore}\nKEV: {kev_category} || Added {nvd_cisaExploitAdd} ({kev_dateDelta})')
    
    nvd_table.append({'cve_ID':x,
                      'nvd_description': nvd_description, 
                      'nvd_published': pd.to_datetime(nvd_published).strftime('%Y-%m-%d'), 
                      'nvd_lastModified': pd.to_datetime(nvd_lastModified).strftime('%Y-%m-%d'),
                      'nvd_vulnStatus': nvd_vulnStatus,
                      'nvd_cisaExploitAdd': pd.to_datetime(nvd_cisaExploitAdd).strftime('%Y-%m-%d'),
                      'nvd_cisaVulnerabilityName': nvd_cisaVulnerabilityName,
                      'nvd_references': nvd_references,
                      'nvd_attackVector': nvd_attackVector,
                      'nvd_attackComplexity': nvd_attackComplexity,
                      'nvd_privilegesRequired': nvd_privilegesRequired,
                      'nvd_userInteraction': nvd_userInteraction,
                      'nvd_baseScore': nvd_baseScore,
                      'nvd_baseSeverity': nvd_baseSeverity,
                      'nvd_exploitabilityScore': nvd_exploitabilityScore,
                      'nvd_impactScore': nvd_impactScore,
                      'nvd_present': nvd_present,
                      'kev_present': kev_present,
                      'kev_dateDelta': kev_dateDelta,
                      'kev_category': kev_category
                      })
    time.sleep(10)
# Out:
# CVE-2022-42948
# Base Score: 9.8
# KEV: 2. KEV, New (0-30) || Added 2023-03-30 (4)
# CVE-2020-14179
# Base Score: 5.3
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2020-24550
# Base Score: 6.1
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2022-24716
# Base Score: 7.5
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2023-27796
# Base Score: *no data*
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2022-38181
# Base Score: 8.8
# KEV: 2. KEV, New (0-30) || Added 2023-03-30 (4)
# CVE-2023-28432
# Base Score: 7.5
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2017-17215
# Base Score: *no data*
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2022-22706
# Base Score: 7.8
# KEV: 2. KEV, New (0-30) || Added 2023-03-30 (4)
# CVE-2014-1776
# Base Score: *no data*
# KEV: 3. KEV, Old (>30) || Added 2022-01-28 (430)
# CVE-2023-23752
# Base Score: 5.3
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2013-3163
# Base Score: *no data*
# KEV: 2. KEV, New (0-30) || Added 2023-03-30 (4)
# CVE-2023-27532
# Base Score: 7.5
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2022-47522
# Base Score: *no data*
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2023-23529
# Base Score: 8.8
# KEV: 3. KEV, Old (>30) || Added 2023-02-14 (48)
# CVE-2023-28343
# Base Score: 9.8
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2023-1790
# Base Score: *no data*
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2021-30900
# Base Score: 7.8
# KEV: 2. KEV, New (0-30) || Added 2023-03-30 (4)
# CVE-2020-17453
# Base Score: 6.1
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2023-29059
# Base Score: *no data*
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2022-39197
# Base Score: 6.1
# KEV: 2. KEV, New (0-30) || Added 2023-03-30 (4)
# CVE-2022-42845
# Base Score: 7.2
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2023-23397
# Base Score: 9.8
# KEV: 2. KEV, New (0-30) || Added 2023-03-14 (20)
# CVE-2023-0266
# Base Score: 7.8
# KEV: 2. KEV, New (0-30) || Added 2023-03-30 (4)
# CVE-2017-7494
# Base Score: 9.8
# KEV: 2. KEV, New (0-30) || Added 2023-03-30 (4)
# CVE-2020-2551
# Base Score: 9.8
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2023-24366
# Base Score: *no data*
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2022-3038
# Base Score: 8.8
# KEV: 2. KEV, New (0-30) || Added 2023-03-30 (4)
# CVE-2019-12922
# Base Score: 6.5
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2022-44268
# Base Score: 6.5
# KEV: 1. Not in KEV || Added 1900-01-01 (0)
# CVE-2023-20963
# Base Score: 7.8
# KEV: 1. Not in KEV || Added 1900-01-01 (0)

# %%
df_nvd = pd.DataFrame(nvd_table)

# %%
#combine dfs
for x in df_nvd['cve_ID']:
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['kev_present']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['kev_present']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_present']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_present']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_published']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_published']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_lastModified']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_lastModified']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_vulnStatus']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_vulnStatus']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_cisaExploitAdd']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_cisaExploitAdd']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_cisaVulnerabilityName']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_cisaVulnerabilityName']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_description']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_description']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_attackVector']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_attackVector']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_attackComplexity']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_attackComplexity']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_privilegesRequired']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_privilegesRequired']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_userInteraction']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_userInteraction']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_baseScore']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_baseScore']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_baseSeverity']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_baseSeverity']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_exploitabilityScore']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_exploitabilityScore']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_impactScore']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_impactScore']].values
    # df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['nvd_references']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['nvd_references']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['kev_dateDelta']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['kev_dateDelta']].values
    df_cve_main.loc[(df_cve_main['cve_ID'] == x), ['kev_category']] = df_nvd.loc[(df_nvd['cve_ID'] == x), ['kev_category']].values
# print(df_cve_main)

# %%
df_updated_db = pd.concat([df_csv,df_cve_main],ignore_index=True)
df_updated_db.drop_duplicates('report_key', inplace = True)

# %%
# Add 'context' column
def context(tweet):
    
    tweet = tweet.lower()
    tweet = tweet.replace('#','')
    poc = ['concept','proof','poc','exploit code','poc_link']
    exploitation = ['zeroday','actively', 'active', 'wild','0day','0-day','zero','exploitation','zero-day']
    c_value = 'none'

    for keyword in poc:
        if bool(re.search(keyword,tweet)):
            # print(tweet)
            # print(f'{keyword}: {bool(re.search(keyword,tweet))}')
            c_value = 'poc'
    for keyword in exploitation:
        if bool(re.search(keyword,tweet)):
            # print(tweet)
            # print(f'{keyword}: {bool(re.search(keyword,tweet))}')
            c_value = 'exploitation'
    return c_value

df_updated_db['tweet_exploitContext'] = df_updated_db['tweet_content'].apply(context)
df_cve_main['tweet_exploitContext'] = df_updated_db['tweet_exploitContext']

# %%
df_updated_db.to_csv('cve_db.csv', mode='w', header=True, index=False)
# df_updated_db.to_excel('cve_db.xlsx', index = None, header=True)
# df_updated_db.to_csv('test_success.csv',mode='w',header=True,index=False)

# %%
# Read CSV file into a pandas dataframe
# df = pd.read_csv('path/to/csv')

# Create a new workbook object
wb = openpyxl.Workbook()

# Create a new worksheet object
ws = wb.create_sheet('Sheet1')

# Write data from dataframe to worksheet
for r in dataframe_to_rows(df_updated_db, index=False, header=True):
    ws.append(r)

# Define the table range
table_range = ws.dimensions

# Add table to worksheet
tab = Table(displayName="table1", ref=table_range)
ws.add_table(tab)

# Save the workbook
wb.save('cve_db.xlsx')

# %%
# Measure rows added
db1 = len(df_csv)
db2 = len(df_updated_db)
kev_stat = df_cve_main['kev_present'].value_counts()
context_stat = df_cve_main['tweet_exploitContext'].value_counts()
print(f'Complete! \n{current_time}\n\nOriginal DF Length: {db1}\nNew DF Length: {db2}\nNew entries: {db2-db1}')
print(f'\n{kev_stat}\n\n{context_stat}')
# Out:
# Complete!
# 2023-04-03 08:22:54.219235
#
# Original DF Length: 92
# New DF Length: 102
# New entries: 10
#
# False    40
# True     14
# Name: kev_present, dtype: int64
#
# exploitation    42
# poc             10
# none             2
# Name: tweet_exploitContext, dtype: int64
